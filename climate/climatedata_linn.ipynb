# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import numpy as np
# Out:
# /home/linn/.local/share/virtualenvs/forFATS-Ce3XM25d/lib/python3.4/importlib/_bootstrap.py:321: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   return f(*args, **kwds)

# %%
from pandas.core import datetools

# %%
pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (20, 10)
# Out:
# /home/linn/.local/share/virtualenvs/forFATS-Ce3XM25d/lib/python3.4/site-packages/IPython/core/interactiveshell.py:2910: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
temp=pd.read_csv("data/CDO1720597417975.csv",sep=',',index_col=' YEARMODA',parse_dates=[2])

# %%
temp.head()
# Out:
#             STN---  WBAN      TEMP         DEWP    .1    SLP      .2    STP    \
#  YEARMODA
# 1957-12-31  433710  99999     79.2   4     73.3     4   1011.6     4   9999.9
# 1958-02-05  433710  99999     77.8   4     71.5     4   1010.0     4   9999.9
# 1958-11-11  433710  99999     79.5   4     74.5     4   1009.2     4   9999.9
# 1961-01-11  433710  99999     77.4   5     72.8     5   1011.1     5   9999.9
# 1961-01-12  433710  99999     79.0   5     72.8     5   1010.6     5   9999.9
#
#               .3     ...         WDSP    .5   MXSPD    GUST     MAX    \
#  YEARMODA            ...
# 1957-12-31     0     ...          3.1     4     4.1   999.9     88.0
# 1958-02-05     0     ...          2.0     4     4.1   999.9     82.0*
# 1958-11-11     0     ...          4.0     4     5.1   999.9     88.0
# 1961-01-11     0     ...          5.6     5     7.0   999.9     82.0*
# 1961-01-12     0     ...          3.0     5     5.1   999.9     86.0*
#
#               MIN    PRCP    SNDP   FRSHTT  Unnamed: 22
#  YEARMODA
# 1957-12-31    75.0    0.59G  999.9       0          NaN
# 1958-02-05    73.0    0.00G  999.9       0          NaN
# 1958-11-11    75.0    0.00I  999.9      10          NaN
# 1961-01-11    72.0    1.73G  999.9   10000          NaN
# 1961-01-12    72.0    0.12G  999.9   10000          NaN
#
# [5 rows x 22 columns]

# %%
temp.columns
# Out:
# Index(['STN---', 'WBAN ', '   TEMP', '  ', '   DEWP', '  .1', '  SLP  ',
#        '  .2', '  STP  ', '  .3', ' VISIB', '  .4', '  WDSP', '  .5', ' MXSPD',
#        '  GUST', '   MAX  ', '  MIN  ', 'PRCP  ', 'SNDP ', ' FRSHTT',
#        'Unnamed: 22'],
#       dtype='object')

# %%
temp['   TEMP']
# Out:
#  YEARMODA
# 1957-12-31    79.2
# 1958-02-05    77.8
# 1958-11-11    79.5
# 1961-01-11    77.4
# 1961-01-12    79.0
# 1961-01-13    79.8
# 1961-01-14    81.0
# 1961-01-15    77.3
# 1961-01-16    80.5
# 1961-01-17    78.6
# 1961-01-18    78.8
# 1961-01-19    78.3
# 1961-01-20    81.2
# 1961-01-21    78.7
# 1961-01-22    78.3
# 1961-01-23    79.0
# 1961-01-24    80.5
# 1961-01-25    78.8
# 1961-01-29    79.3
# 1961-01-30    79.7
# 1961-01-31    80.7
# 1961-02-01    79.2
# 1961-02-03    79.4
# 1961-02-04    78.8
# 1961-02-08    80.2
# 1961-02-09    78.8
# 1961-02-10    78.3
# 1961-02-11    79.8
# 1961-02-22    81.0
# 1961-02-25    81.5
#               ...
# 2017-07-03    80.4
# 2017-07-04    82.8
# 2017-07-05    82.7
# 2017-07-06    81.6
# 2017-07-07    81.9
# 2017-07-08    80.7
# 2017-07-09    80.0
# 2017-07-10    79.9
# 2017-07-11    79.5
# 2017-07-12    81.4
# 2017-07-13    81.0
# 2017-07-14    81.3
# 2017-07-15    82.2
# 2017-07-16    81.2
# 2017-07-17    82.4
# 2017-07-18    81.6
# 2017-07-19    80.7
# 2017-07-20    79.4
# 2017-07-21    80.8
# 2017-07-22    81.6
# 2017-07-23    81.9
# 2017-07-24    82.9
# 2017-07-25    84.0
# 2017-07-26    82.7
# 2017-07-27    82.4
# 2017-07-28    82.3
# 2017-07-29    82.5
# 2017-07-30    82.5
# 2017-07-31    82.4
# 2017-08-01    81.6
# Name:    TEMP, Length: 16400, dtype: float64

# %%
temp.index
# Out:
# DatetimeIndex(['1957-12-31', '1958-02-05', '1958-11-11', '1961-01-11',
#                '1961-01-12', '1961-01-13', '1961-01-14', '1961-01-15',
#                '1961-01-16', '1961-01-17',
#                ...
#                '2017-07-23', '2017-07-24', '2017-07-25', '2017-07-26',
#                '2017-07-27', '2017-07-28', '2017-07-29', '2017-07-30',
#                '2017-07-31', '2017-08-01'],
#               dtype='datetime64[ns]', name=' YEARMODA', length=16400, freq=None)

# %%
#temp.set_index([' YEARMODA'])

# %%
temp.plot.line(y='   TEMP')
# Out:
# /home/linn/.local/share/virtualenvs/forFATS-Ce3XM25d/lib/python3.4/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#y=temp['   TEMP']

# %%
#temp['   TEMP']

# %%
y=temp['   TEMP'].resample("MS").mean()

# %%
y.isnull().sum()
y = y.fillna(y.bfill())

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 11, 9

decomposition = sm.tsa.seasonal_decompose(y, model='additive')
fig = decomposition.plot()
plt.show()
# Out:
# /home/linn/.local/share/virtualenvs/forFATS-Ce3XM25d/lib/python3.4/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['monospace'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
